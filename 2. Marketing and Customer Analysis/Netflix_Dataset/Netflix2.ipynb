# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import Dataset

# %%
Data=pd.read_csv('/content/drive/MyDrive/Data/Netflix-Dataset.csv')
Data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %% [markdown]
# Getting to Know The Variables

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
Data.describe()
# Out:
#        Show_Id Category              Title                Director  \
# count     7789     7789               7789                    5401
# unique    7787        2               7787                    4050
# top      s6621    Movie  The Lost Okoroshi  Raúl Campos, Jan Suter
# freq         2     5379                  2                      18
#
#                       Cast        Country     Release_Date Rating  Duration  \
# count                 7071           7282             7779   7782      7789
# unique                6831            681             1565     14       216
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    18           2556              118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# top     Documentaries  Multiple women report their husbands as missin...
# freq              334                                                  3

# %%
Data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
Data.shape
# Out:
# (7789, 11)

# %%
Data.size ## columns* rows
# Out:
# 85679

# %%
Data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# Missing Values

# %%
pd.DataFrame(Data.isna().sum(),columns=['Number of Missing Values'])
# Out:
#               Number of Missing Values
# Show_Id                              0
# Category                             0
# Title                                0
# Director                          2388
# Cast                               718
# Country                            507
# Release_Date                        10
# Rating                               7
# Duration                             0
# Type                                 0
# Description                          0

# %%
pd.DataFrame(Data.nunique(), columns=['Number of Unique Values'])
# Out:
#               Number of Unique Values
# Show_Id                          7787
# Category                            2
# Title                            7787
# Director                         4050
# Cast                             6831
# Country                           681
# Release_Date                     1565
# Rating                             14
# Duration                          216
# Type                              492
# Description                      7769

# %% [markdown]
# Duplicated

# %%
Data.duplicated().sum()
# Out:
# 2

# %%
Data[Data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# As it's obvious they aren't duplicate so we keep them!

# %% [markdown]
# #Data cleaning

# %% [markdown]
# ###Correcting The Data Types

# %%
Data['Release_Date']=pd.to_datetime(Data['Release_Date'],format='mixed')
Data['Release_Date']
#Data['Release_Date']=pd.to_datetime(Data['Release_Date'],format='ISO8601')
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: Release_Date, Length: 7789, dtype: datetime64[ns]

# %%
Data['Release_Date'].isnull().sum()
# Out:
# 10

# %%
#Data.dropna(subset=['Release_Date'],inplace=True) # Removed Missing values
Data['Release_Date']=Data['Release_Date'].fillna(Data['Release_Date'].mode()[0])

# %% [markdown]
# ###Rating variable

# %%
Data['Rating'].isnull().sum()
# Out:
# 7

# %%
#Data.dropna(subset=['Rating'], inplace=True) # Removed Missing values
Data['Rating']=Data['Rating'].fillna(Data['Rating'].mode()[0])

# %% [markdown]
# ### Filling Missing Values Of Director, Country, Cast Variables

# %%
Data[['Director', 'Cast', 'Country']]=Data[['Director', 'Cast', 'Country']].fillna('Unknown')

# %%
# Recheck Missing values
Data.isna().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %% [markdown]
# #Exploratory Data Analysis #1

# %% [markdown]
# ####Search Movies By Year, Category

# %%
def filter_by_Year_Category(Data,Year,Category,n):
  return Data[(Data['Category']==Category) & (Data['Release_Date'].dt.year==Year)][['Title', 'Director', 'Cast', 'Country','Release_Date', 'Rating', 'Duration', 'Type', 'Description']].head(n)

# %%
filter_by_Year_Category(Data,2020,"Movie",2)
# Out:
#   Title         Director                                               Cast  \
# 4    21   Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6   122  Yasir Al Yasiri  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
#
#          Country Release_Date Rating Duration  \
# 4  United States   2020-01-01  PG-13  123 min
# 6          Egypt   2020-06-01  TV-MA   95 min
#
#                                   Type  \
# 4                               Dramas
# 6  Horror Movies, International Movies
#
#                                          Description
# 4  A brilliant group of students become card-coun...
# 6  After an awful accident, a couple admitted to ...

# %% [markdown]
# ####Search Movies/Series By Country

# %%
def filter_by_Country(Data,Country,n):
  return Data[(Data['Country']==Country)][['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Release_Date', 'Rating', 'Duration', 'Type', 'Description']].set_index('Show_Id').head(n)

# %%
filter_by_Country(Data,'Egypt',5)
# Out:
#         Category                         Title         Director  \
# Show_Id
# s7         Movie                           122  Yasir Al Yasiri
# s104       Movie             30 Days of Luxury       Hani Hamdi
# s281       Movie                     Abdo Mota          Unknown
# s372       Movie  Alarmoty in the Land of Fire          Unknown
# s448       Movie                  Amar's Hands   Khaled Youssef
#
#                                                       Cast Release_Date  \
# Show_Id
# s7       Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...   2020-06-01
# s104     Taher Farouz, Sad Al-Saghir, Ahmad Faloks, Sol...   2019-04-18
# s281                                       Mohamed Ramadan   2019-04-19
# s372                                               Unknown   2019-08-05
# s448     Ghadah Abdulrazeq, Wafaa Amer, Hassan El Radda...   2019-04-26
#
#         Rating Duration                                              Type  \
# Show_Id
# s7       TV-MA   95 min               Horror Movies, International Movies
# s104     TV-14   91 min                    Comedies, International Movies
# s281     TV-MA  100 min  Action & Adventure, Dramas, International Movies
# s372     TV-MA   94 min                    Comedies, International Movies
# s448     TV-14  125 min                      Dramas, International Movies
#
#                                                Description
# Show_Id
# s7       After an awful accident, a couple admitted to ...
# s104     With the help of his friends, a man breaks out...
# s281     Following the mysterious death of his parents,...
# s372     While vacationing at a resort, an ornery and o...
# s448     To fulfill her husband’s dream to build a home...

# %% [markdown]
# ####Search Top Directors Based on Most Movies They Have Produced.

# %%
def Top_Directors(Data,n):
  return Data['Director'].value_counts().to_frame().head(n)

# %%
Top_Directors(Data,5)
# Out:
#                         count
# Director
# Unknown                  2388
# Raúl Campos, Jan Suter     18
# Marcus Raboy               16
# Jay Karas                  14
# Cathy Garcia-Molina        13

# %% [markdown]
# ####Number Of Movies/Series Released Per Year

# %%
def Number_of_Movies_per_Year(Data):
  Data['Release_Date']=Data['Release_Date'].dt.year
  return Data['Release_Date'].value_counts().to_frame().sort_index()

# %%
Number_of_Movies_per_Year(Data)
# Out:
#               count
# Release_Date
# 2008              2
# 2009              2
# 2010              1
# 2011             13
# 2012              3
# 2013             11
# 2014             25
# 2015             88
# 2016            443
# 2017           1225
# 2018           1685
# 2019           2154
# 2020           2020
# 2021            117

# %% [markdown]
# #### Add the column Number_of_Cast & Search Number of Movies/Series the Cast play in

# %%
Data['Cast'].head(2)
# Out:
# 0    João Miguel, Bianca Comparato, Michel Gomes, R...
# 1    Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# Name: Cast, dtype: object

# %%
list_cast_Number=[]
for i in range(0,Data['Cast'].size):
  cast_Number=len(str(Data['Cast'][i]).split(','))
  list_cast_Number.append(cast_Number)
Data.insert(5,'Number_of_Cast',list_cast_Number)
Data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast  Number_of_Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...              11  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...               6  Mexico
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
def Count_Work_Cast_play(Data,Name):
  number=0
  for i in range(0,Data['Cast'].size):
    if str(Data['Cast'][i]).split(',').count(Name)==1:
      number+=1
  return number

# %%
Count_Work_Cast_play(Data,'David Attenborough')
# Out:
# 18

# %% [markdown]
# ##### Cast Analysis DataFrame

# %%
#### Not Complete
df_Cast=pd.DataFrame(Data['Cast'])
df_Cast['Cast'] = df_Cast['Cast'].str.split(',') # Split text into a list
df_Cast=df_Cast.explode('Cast') # Convert list into multiple rows
df_Cast = df_Cast.drop_duplicates() # Clean and transform data
df_Cast = df_Cast.reset_index(drop=True)

df_Cast[['First Name', 'Last Name']] = df_Cast['Cast'].str.split(n=1, expand=True)
df_Cast.drop('Cast',axis=1) # Clean data
dups = df_Cast.pivot_table(index = ['First Name', 'Last Name'], aggfunc ='size')
print(dups)
# Out:
# First Name  Last Name
# "Riley"     Lakdhar Dridi            1
# 'Najite     Dede                     2
# 2           Chainz                   1
# 50          Cent                     2
# A           Boogie Wit tha Hoodie    1
#                                     ..
# Şerif       Sezer                    1
# Şinasi      Yurtsever                1
# Şükran      Ovalı                    1
# Şükrü       Özyıldız                 2
# Ṣọpẹ́       Dìrísù                   1
# Length: 32268, dtype: int64
